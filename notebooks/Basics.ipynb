# %% [markdown]
# This notebook provides an overview of you can use CEBRA:
# - in different modes
# - across different sessions/animals
# - across different modalities.
#
# These examples can be found on the demos they provide on their webpage. They are directly retrieved from  some of those notebooks. This notebook highlights what we think are the important pieces to get started using CEBRA.

# %%
! pip install --pre 'cebra[datasets,demos]'
# Out:
# Requirement already satisfied: cebra[datasets,demos] in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: joblib in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (1.4.2)
# Requirement already satisfied: literate-dataclasses in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (0.0.6)
# Requirement already satisfied: scikit-learn in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (1.5.0)
# Requirement already satisfied: scipy in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (1.10.1)
# Requirement already satisfied: torch in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (2.3.1)
# Requirement already satisfied: tqdm in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (4.66.4)
# Requirement already satisfied: matplotlib in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (3.8.4)
# Requirement already satisfied: requests in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (2.32.2)
# Requirement already satisfied: ipykernel in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (6.29.4)
# Collecting jupyter (from cebra[datasets,demos])
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting nbconvert (from cebra[datasets,demos])
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: seaborn in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (0.13.2)
# Requirement already satisfied: h5py in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (3.11.0)
# Requirement already satisfied: pandas in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from cebra[datasets,demos]) (2.2.2)
# Collecting nlb-tools (from cebra[datasets,demos])
#   Using cached nlb_tools-0.0.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting hdf5storage (from cebra[datasets,demos])
#   Using cached hdf5storage-0.1.19-py2.py3-none-any.whl.metadata (24 kB)
# Collecting openpyxl (from cebra[datasets,demos])
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from h5py->cebra[datasets,demos]) (1.26.4)
# Requirement already satisfied: appnope in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (1.6.0)
# Requirement already satisfied: packaging in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (23.2)
# Requirement already satisfied: psutil in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipykernel->cebra[datasets,demos]) (5.14.3)
# Collecting notebook (from jupyter->cebra[datasets,demos])
#   Downloading notebook-7.3.0a1-py3-none-any.whl.metadata (10 kB)
# Collecting qtconsole (from jupyter->cebra[datasets,demos])
#   Downloading qtconsole-5.5.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter->cebra[datasets,demos])
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting ipywidgets (from jupyter->cebra[datasets,demos])
#   Downloading ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from matplotlib->cebra[datasets,demos]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from matplotlib->cebra[datasets,demos]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from matplotlib->cebra[datasets,demos]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from matplotlib->cebra[datasets,demos]) (1.4.4)
# Requirement already satisfied: pillow>=8 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from matplotlib->cebra[datasets,demos]) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from matplotlib->cebra[datasets,demos]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from matplotlib->cebra[datasets,demos]) (2.9.0.post0)
# Collecting beautifulsoup4 (from nbconvert->cebra[datasets,demos])
#   Downloading beautifulsoup4-4.13.0b2-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert->cebra[datasets,demos])
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->cebra[datasets,demos])
#   Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: jinja2>=3.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from nbconvert->cebra[datasets,demos]) (3.1.4)
# Collecting jupyterlab-pygments (from nbconvert->cebra[datasets,demos])
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markupsafe>=2.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from nbconvert->cebra[datasets,demos]) (2.1.5)
# Collecting mistune<4,>=2.0.3 (from nbconvert->cebra[datasets,demos])
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->cebra[datasets,demos])
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->cebra[datasets,demos])
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->cebra[datasets,demos])
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pygments>=2.4.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from nbconvert->cebra[datasets,demos]) (2.18.0)
# Collecting tinycss2 (from nbconvert->cebra[datasets,demos])
#   Using cached tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting pandas (from cebra[datasets,demos])
#   Downloading pandas-1.3.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: pynwb in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from nlb-tools->cebra[datasets,demos]) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from pandas->cebra[datasets,demos]) (2024.1)
# Collecting et-xmlfile (from openpyxl->cebra[datasets,demos])
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from requests->cebra[datasets,demos]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from requests->cebra[datasets,demos]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from requests->cebra[datasets,demos]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from requests->cebra[datasets,demos]) (2024.6.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from scikit-learn->cebra[datasets,demos]) (3.5.0)
# Requirement already satisfied: filelock in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from torch->cebra[datasets,demos]) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from torch->cebra[datasets,demos]) (4.12.2)
# Requirement already satisfied: sympy in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from torch->cebra[datasets,demos]) (1.12.1)
# Requirement already satisfied: networkx in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from torch->cebra[datasets,demos]) (3.3)
# Requirement already satisfied: fsspec in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from torch->cebra[datasets,demos]) (2024.6.0)
# Requirement already satisfied: six>=1.9.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->cebra[datasets,demos]) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert->cebra[datasets,demos])
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: decorator in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (3.0.47)
# Requirement already satisfied: stack-data in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.6.2)
# Requirement already satisfied: exceptiongroup in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->cebra[datasets,demos]) (3.10.0)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->cebra[datasets,demos])
#   Downloading fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: jsonschema>=2.6 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->cebra[datasets,demos]) (4.22.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->cebra[datasets,demos])
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting widgetsnbextension~=4.0.11 (from ipywidgets->jupyter->cebra[datasets,demos])
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.11 (from ipywidgets->jupyter->cebra[datasets,demos])
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter->cebra[datasets,demos])
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook->jupyter->cebra[datasets,demos])
#   Downloading jupyterlab_server-2.27.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.4,>=4.3.0a1 (from notebook->jupyter->cebra[datasets,demos])
#   Downloading jupyterlab-4.3.0a2-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter->cebra[datasets,demos])
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: hdmf>=3.14.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from pynwb->nlb-tools->cebra[datasets,demos]) (3.14.1)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter->cebra[datasets,demos])
#   Using cached QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from sympy->torch->cebra[datasets,demos]) (1.3.0)
# Requirement already satisfied: ruamel-yaml>=0.16 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from hdmf>=3.14.0->pynwb->nlb-tools->cebra[datasets,demos]) (0.18.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->cebra[datasets,demos]) (0.18.1)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.4,>=4.3.0a1->notebook->jupyter->cebra[datasets,demos])
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab<4.4,>=4.3.0a1->notebook->jupyter->cebra[datasets,demos])
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.4,>=4.3.0a1->notebook->jupyter->cebra[datasets,demos])
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.1.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from jupyterlab<4.4,>=4.3.0a1->notebook->jupyter->cebra[datasets,demos]) (69.5.1)
# Collecting tomli>=1.2.2 (from jupyterlab<4.4,>=4.3.0a1->notebook->jupyter->cebra[datasets,demos])
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->cebra[datasets,demos])
#   Downloading Babel-2.15.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->cebra[datasets,demos])
#   Using cached json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->cebra[datasets,demos]) (0.2.2)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.0a1->notebook->jupyter->cebra[datasets,demos])
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.0a1->notebook->jupyter->cebra[datasets,demos])
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Downloading PyYAML-6.0.2rc1-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/brian.gitahi/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages (from ruamel-yaml>=0.16->hdmf>=3.14.0->pynwb->nlb-tools->cebra[datasets,demos]) (0.2.8)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Downloading webcolors-24.6.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Downloading cffi-1.17.0rc1-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->cebra[datasets,demos])
#   Using cached types_python_dateutil-2.9.0.20240316-py3-none-any.whl.metadata (1.8 kB)
# Using cached hdf5storage-0.1.19-py2.py3-none-any.whl (53 kB)
# Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached nlb_tools-0.0.3-py3-none-any.whl (39 kB)
# Downloading pandas-1.3.4-cp310-cp310-macosx_11_0_arm64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 5.1 MB/s eta 0:00:00 0:00:01m
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 45.3 MB/s eta 0:00:00
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading beautifulsoup4-4.13.0b2-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 27.2 MB/s eta 0:00:00
# Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl (25 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 23.3 MB/s eta 0:00:00
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading notebook-7.3.0a1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 51.1 MB/s eta 0:00:00a 0:00:01
# Downloading qtconsole-5.5.2-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 19.7 MB/s eta 0:00:00
# Using cached tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Downloading fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Downloading jupyter_server-2.14.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 22.0 MB/s eta 0:00:00
# Downloading jupyterlab-4.3.0a2-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 57.5 MB/s eta 0:00:00a 0:00:01
# Downloading jupyterlab_server-2.27.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 12.7 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 23.1 MB/s eta 0:00:00
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 61.9 MB/s eta 0:00:00
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.2 MB/s eta 0:00:00
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading Babel-2.15.0-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 55.4 MB/s eta 0:00:00a 0:00:01
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached json5-0.9.25-py3-none-any.whl (30 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading PyYAML-6.0.2rc1-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 25.9 MB/s eta 0:00:00
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading cffi-1.17.0rc1-cp310-cp310-macosx_11_0_arm64.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.3/178.3 kB 21.4 MB/s eta 0:00:00
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.6.0-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, types-python-dateutil, tomli, tinycss2, terminado, soupsieve, sniffio, send2trash, rfc3986-validator, rfc3339-validator, qtpy, pyyaml, python-json-logger, pycparser, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, h11, fqdn, et-xmlfile, defusedxml, bleach, babel, async-lru, pandas, openpyxl, jupyter-server-terminals, httpcore, hdf5storage, cffi, beautifulsoup4, arrow, anyio, isoduration, httpx, argon2-cffi-bindings, nbformat, ipywidgets, argon2-cffi, qtconsole, nbclient, jupyter-events, jupyter-console, nlb-tools, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# Successfully installed anyio-4.4.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 babel-2.15.0 beautifulsoup4-4.13.0b2 bleach-6.1.0 cffi-1.17.0rc1 defusedxml-0.8.0rc2 et-xmlfile-1.1.0 fastjsonschema-2.20.0 fqdn-1.5.1 h11-0.14.0 hdf5storage-0.1.19 httpcore-1.0.5 httpx-0.27.0 ipywidgets-8.1.3 isoduration-20.11.0 json5-0.9.25 jsonpointer-3.0.0 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.3.0a2 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.2 jupyterlab-widgets-3.0.11 mistune-3.0.2 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 nlb-tools-0.0.3 notebook-7.3.0a1 notebook-shim-0.2.4 openpyxl-3.1.5 overrides-7.7.0 pandas-1.3.4 pandocfilters-1.5.1 prometheus-client-0.20.0 pycparser-2.22 python-json-logger-2.0.7 pyyaml-6.0.2rc1 qtconsole-5.5.2 qtpy-2.4.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.5 terminado-0.18.1 tinycss2-1.3.0 tomli-2.0.1 types-python-dateutil-2.9.0.20240316 uri-template-1.3.0 webcolors-24.6.0 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.11

# %%
import sys
import os # my addtion

import numpy as np
import itertools
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import solve_ivp
import cebra.data
import torch
import cebra.integrations
import cebra.datasets
from cebra import CEBRA
import torch
import pickle
import cebra_pack.utils as cp

from matplotlib.collections import LineCollection
import pandas as pd

# %% [markdown]
# Let's load the data that we'll be using first.

# %%
# these are neural recordings from the hippocampus of different rats combined with behavioural data -
# (the position + direction of the rats along a linear track)

hippocampus_a = cebra.datasets.init('rat-hippocampus-single-achilles')
hippocampus_b = cebra.datasets.init('rat-hippocampus-single-buddy')
hippocampus_c = cebra.datasets.init('rat-hippocampus-single-cicero')
hippocampus_g = cebra.datasets.init('rat-hippocampus-single-gatsby')
# Out:
# 100%|██████████| 10.0M/10.0M [00:03<00:00, 2.68MB/s]
# Download complete. Dataset saved in 'data/rat_hippocampus/achilles.jl'
# 100%|██████████| 2.68M/2.68M [00:02<00:00, 1.04MB/s]
# Download complete. Dataset saved in 'data/rat_hippocampus/buddy.jl'
# 100%|██████████| 22.0M/22.0M [00:37<00:00, 588kB/s]
# Download complete. Dataset saved in 'data/rat_hippocampus/cicero.jl'
# 100%|██████████| 9.40M/9.40M [00:08<00:00, 1.09MB/s]
# Download complete. Dataset saved in 'data/rat_hippocampus/gatsby.jl'

# %%
# neural + behaviour data from one rat
hippocampus_pos = cebra.datasets.init('rat-hippocampus-single-achilles')
type(hippocampus_pos)
# Out:
# cebra.registry.add_helper_functions.<locals>.parametrize.<locals>._create_class.<locals>._ParametrizedClass

# %%
# take a quick look at how our data looks
print('neural data shape:',hippocampus_pos.neural.shape)
print('behaviour data shape:',hippocampus_pos.continuous_index.shape)
# Out:
# neural data shape: torch.Size([10178, 120])
# behaviour data shape: torch.Size([10178, 3])

# %%
# use GPU if it's there
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"

# %% [markdown]
# # A. Different Modes
#
# CEBRA has 3 different modes: CEBRA-Time(Discovery Mode), CEBRA-Behaviour (Hypothesis Mode) and CEBRA-Hybrid that's a cross between the two.
#
# ## 1. CEBRA Time

# %% [markdown]
# We start by building the CEBRA-Time model. This type of model is only trained on neural data and produces an embedding based on the existing temporal structure of the input data i.e. points that are close together in time in the input will also be close together on the embedding produced.

# %%
max_iterations = 2000

# %%
# build the model
cebra_time_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1.12,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

# %% [markdown]
# The important parameter that we'll explore here is the **'conditional'** parameter.
#
# NB: Model architecture and distance are also parameters that require some care when changing but we'll look at that in a different notebook.

# %%
# Train the model on neural data only
cebra_time_model.fit(hippocampus_pos.neural)
# Out:
# pos: -0.8233 neg:  6.3877 total:  5.5644 temperature:  1.1200: 100%|██████████| 2000/2000 [00:33<00:00, 59.35it/s]
# CEBRA(batch_size=512, conditional='time', max_iterations=2000,
#       model_architecture='offset10-model', output_dimension=3, temperature=1.12,
#       time_offsets=10, verbose=True)

# %%
# Then transform the input to produce the embedding
cebra_time_embedding = cebra_time_model.transform(hippocampus_pos.neural)

# %% [markdown]
# ## 2. CEBRA Behaviour
#
# Now let's combine neural activity and behavioural labels to construct the manifold embeddings.

# %%
# build the model
cebra_behavior_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

# %% [markdown]
# Here, we change the conditional to be 'time-delta' to allow the algorithm to use the behavioural labels in the construction of the latent space. Note that the label can be continuous(e.g. position in space) or discrete (e.g. binary choice). The example below shows a continuous label being used.

# %%
# train the model using both neural data and behavioural label(s)
cebra_behavior_model.fit(hippocampus_pos.neural, hippocampus_pos.continuous_index.numpy())
# Out:
# pos: -0.8794 neg:  6.4205 total:  5.5411 temperature:  1.0000: 100%|██████████| 2000/2000 [00:32<00:00, 62.31it/s]
# CEBRA(batch_size=512, conditional='time_delta', max_iterations=2000,
#       model_architecture='offset10-model', output_dimension=3, temperature=1,
#       time_offsets=10, verbose=True)

# %%
# then transform the input to produce an embedding - 
cebra_behavior_embedding = cebra_behavior_model.transform(hippocampus_pos.neural)

# %% [markdown]
# note that we only transform the neural data (the behavioural labels are only used in training -- for both the CEBRA-Behaviour and CEBRA-hybrid).

# %% [markdown]
# ## 3. CEBRA - Hybrid

# %%
# build the model
cebra_hybrid_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10,
                        hybrid = True)

# %% [markdown]
# Notice that this model parameters look very similar to the CEBRA-Behaviour ones. The only difference is that here we set the 'hybrid' parameter to 'True'.

# %%
# train the model using both neural data and the behavioural label(s)
cebra_hybrid_model.fit(hippocampus_pos.neural, hippocampus_pos.continuous_index.numpy())
# Out:
# behavior_pos: -0.8748 behavior_neg:  6.4194 behavior_total:  5.5446 time_pos: -0.9030 time_neg:  6.4194 time_total:  5.5164: 100%|██████████| 2000/2000 [00:52<00:00, 38.35it/s]
# CEBRA(batch_size=512, conditional='time_delta', hybrid=True,
#       max_iterations=2000, model_architecture='offset10-model',
#       output_dimension=3, temperature=1, time_offsets=10, verbose=True)

# %%
# transform the input to obtain the embedding
cebra_hybrid_embedding = cebra_hybrid_model.transform(hippocampus_pos.neural)

# %% [markdown]
# Now let's visualise the embeddings

# %%
# group the behaviour labels into either right/left direction
right = hippocampus_pos.continuous_index[:,1] == 1
left = hippocampus_pos.continuous_index[:,2] == 1

# %%
# %matplotlib inline
# then plot the embeddings: making sure to show right vs left direction of motion using different colour maps
# the gradient of the colour map shows the position on the linear track

fig = plt.figure(figsize=(10,2))

ax1 = plt.subplot(141, projection='3d')
ax2 = plt.subplot(142, projection='3d')
ax3 = plt.subplot(143, projection='3d')

for dir, cmap in zip([right, left], ["cool", "viridis"]):
    ax1=cebra.plot_embedding(ax=ax1, embedding=cebra_behavior_embedding[dir,:], embedding_labels=hippocampus_pos.continuous_index[dir,0], title='CEBRA-Behavior', cmap=cmap)
    ax2=cebra.plot_embedding(ax=ax2, embedding=cebra_time_embedding[dir,:], embedding_labels=hippocampus_pos.continuous_index[dir,0], title='CEBRA-Time', cmap=cmap)
    ax3=cebra.plot_embedding(ax=ax3, embedding=cebra_hybrid_embedding[dir,:], embedding_labels=hippocampus_pos.continuous_index[dir,0], title='CEBRA-Hybrid', cmap=cmap)

plt.show()

# %% [markdown]
# # B. Using CEBRA across sessions/animals
#
# We will use CEBRA-Behaviour for this, and the data will be from rats performing the same task as before: running back and forth on a linear track (recordings from the hippocampus).

# %%
# Load the data first
names = ["achilles", "buddy", "cicero", "gatsby"]
datas = [hippocampus_a.neural.numpy(), hippocampus_b.neural.numpy(), hippocampus_c.neural.numpy(), hippocampus_g.neural.numpy()]
labels = [hippocampus_a.continuous_index.numpy(), hippocampus_b.continuous_index.numpy(), hippocampus_c.continuous_index.numpy(), hippocampus_g.continuous_index.numpy()]

# %% [markdown]
# ### Single-session training
#
# Here we train each model only on one set of data. But, we 'align' the datasets to the first one, i.e. we make sure if they had different sizes or number of features* (confirm).

# %%
# single session
embeddings = dict()

# Single session training
for name, X, y in zip(names, datas, labels):
    # Fit one CEBRA model per session (i.e., per rat)
    print(f"Fitting CEBRA for {name}")
    cebra_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

    cebra_model.fit(X, y)
    embeddings[name] = cebra_model.transform(X)


# Align the single session embeddings to the first rat
alignment = cebra.data.helper.OrthogonalProcrustesAlignment()
first_rat = list(embeddings.keys())[0]

for j, rat_name in enumerate(list(embeddings.keys())[1:]):
    embeddings[f"{rat_name}"] = alignment.fit_transform(
        embeddings[first_rat], embeddings[rat_name], labels[0], labels[j+1])


# Save embeddings in current folder
with open('embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings, f)
# Out:
# Fitting CEBRA for achilles
# pos: -0.8675 neg:  6.4209 total:  5.5533 temperature:  1.0000: 100%|██████████| 2000/2000 [00:32<00:00, 60.85it/s]
# Fitting CEBRA for buddy
# pos: -0.7044 neg:  6.4546 total:  5.7502 temperature:  1.0000: 100%|██████████| 2000/2000 [00:31<00:00, 62.79it/s]
# Fitting CEBRA for cicero
# pos: -0.5449 neg:  6.5088 total:  5.9639 temperature:  1.0000: 100%|██████████| 2000/2000 [00:33<00:00, 59.55it/s]
# Fitting CEBRA for gatsby
# pos: -0.7240 neg:  6.4635 total:  5.7395 temperature:  1.0000: 100%|██████████| 2000/2000 [00:32<00:00, 62.36it/s]

# %% [markdown]
# ### Multisession training
# Here, we train one model on all the sessions and then transform the individual datasets to get individual embeddings for the different animals.

# %%
multi_embeddings = dict()

# Multisession training
multi_cebra_model = CEBRA(model_architecture='offset10-model',
                    batch_size=512,
                    learning_rate=3e-4,
                    temperature=1,
                    output_dimension=3,
                    max_iterations=max_iterations,
                    distance='cosine',
                    conditional='time_delta',
                    device='cuda_if_available',
                    verbose=True,
                    time_offsets=10)

# Provide a list of data, i.e. datas = [data_a, data_b, ...]
multi_cebra_model.fit(datas, labels)

# Transform each session with the right model, by providing the corresponding session ID
for i, (name, X) in enumerate(zip(names, datas)):
    multi_embeddings[name] = multi_cebra_model.transform(X, session_id=i)

# Save embeddings in current folder
with open('multi_embeddings.pkl', 'wb') as f:
    pickle.dump(multi_embeddings, f)
# Out:
# pos: -0.6704 neg:  7.8052 total:  7.1349 temperature:  1.0000: 100%|██████████| 2000/2000 [08:44<00:00,  3.82it/s]

# %% [markdown]
# ### Compare embeddings
#
# Now we compare the single-session and multi-sessions embeddings.

# %%
with open('embeddings.pkl', 'rb') as f:
    embeddings = pickle.load(f)
with open('multi_embeddings.pkl', 'rb') as f:
    multi_embeddings = pickle.load(f)

# %%
# they made a custom function to plot the embeddings using the right/left labels they made
def plot_hippocampus(ax, embedding, label, gray = False, idx_order = (0,1,2)):
    r_ind = label[:,1] == 1
    l_ind = label[:,2] == 1

    if not gray:
        r_cmap = 'cool'
        l_cmap = 'viridis'
        r_c = label[r_ind, 0]
        l_c = label[l_ind, 0]
    else:
        r_cmap = None
        l_cmap = None
        r_c = 'gray'
        l_c = 'gray'

    idx1, idx2, idx3 = idx_order
    r=ax.scatter(embedding [r_ind,idx1],
               embedding [r_ind,idx2],
               embedding [r_ind,idx3],
               c=r_c,
               cmap=r_cmap, s=0.05, alpha=0.75)
    l=ax.scatter(embedding [l_ind,idx1],
               embedding [l_ind,idx2],
               embedding [l_ind,idx3],
               c=l_c,
               cmap=l_cmap, s=0.05, alpha=0.75)

    ax.grid(False)
    ax.xaxis.pane.fill = False
    ax.yaxis.pane.fill = False
    ax.zaxis.pane.fill = False
    ax.xaxis.pane.set_edgecolor('w')
    ax.yaxis.pane.set_edgecolor('w')
    ax.zaxis.pane.set_edgecolor('w')

    return ax

# %%
# %matplotlib inline

fig = plt.figure(figsize=(10,6))

ax1 = plt.subplot(241, projection='3d')
ax2 = plt.subplot(242, projection='3d')
ax3 = plt.subplot(243, projection='3d')
ax4 = plt.subplot(244, projection='3d')
axs = [ax1, ax2, ax3, ax4]

ax5 = plt.subplot(245, projection='3d')
ax6 = plt.subplot(246, projection='3d')
ax7 = plt.subplot(247, projection='3d')
ax8 = plt.subplot(248, projection='3d')
axs_multi = [ax5, ax6, ax7, ax8]

for name, label, ax, ax_multi in zip(names, labels, axs, axs_multi):
    ax = plot_hippocampus(ax, embeddings[name], label)
    ax.set_title(f'Single-{name}', y=1, pad=-20)
    ax.axis('off')
    ax_multi = plot_hippocampus(ax_multi, multi_embeddings[name], label)
    ax_multi.set_title(f'Multi-{name}', y=1, pad=-20)
    ax_multi.axis('off')


plt.subplots_adjust(wspace=0,
                    hspace=0)
plt.show()

# %% [markdown]
# You can verify that these embeddings are indeed consistent by running the 'cebra.sklearn.metrics.consistency_score' function and plotting the consistency scores as shown in the demo notebook on ' Training models across animals'.

# %% [markdown]
# # C. Using CEBRA across modalities (Bonus)
#
# Here, we show a brief example of how you can combine NP and Ca imaging datasets to train a model and then produce consistent embeddings for the individual datasets. For a more detailed overview, visit the CEBRA website and check out the notebook 'Decoding movie features from (V1) visual cortex'.

# %% [markdown]
# ### Load data

# %%
cortex = 'VISp'
seed=333
num_neurons = 800

ca_train = cebra.datasets.init(f'allen-movie-one-ca-{cortex}-{num_neurons}-train-10-{seed}')
np_train = cebra.datasets.init(f'allen-movie-one-neuropixel-{cortex}-{num_neurons}-train-10-{seed}')
joint_train = cebra.datasets.init(f'allen-movie-one-ca-neuropixel-{cortex}-{num_neurons}-train-10-{seed}')

ca_test = cebra.datasets.init(f'allen-movie-one-ca-{cortex}-{num_neurons}-test-10-{seed}')
np_test = cebra.datasets.init(f'allen-movie-one-neuropixel-{cortex}-{num_neurons}-test-10-{seed}')
joint_test = cebra.datasets.init(f'allen-movie-one-ca-neuropixel-{cortex}-{num_neurons}-test-10-{seed}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 5
#       2 seed=333
#       3 num_neurons = 800
# ----> 5 ca_train = cebra.datasets.init(f'allen-movie-one-ca-{cortex}-{num_neurons}-train-10-{seed}')
#       6 np_train = cebra.datasets.init(f'allen-movie-one-neuropixel-{cortex}-{num_neurons}-train-10-{seed}')
#       7 joint_train = cebra.datasets.init(f'allen-movie-one-ca-neuropixel-{cortex}-{num_neurons}-train-10-{seed}')
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/cebra/registry.py:244, in add_helper_functions.<locals>.init(name, *args, **kwargs)
#     233 def init(name: str, *args, **kwargs):
#     234     """Initialize an instance from the registry with the specified arguments.
#     235
#     236     Args:
#    (...)
#     242         An instance of the specified class.
#     243     """
# --> 244     return _Registry.init(module, name, *args, **kwargs)
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/cebra/registry.py:105, in _Registry.init(cls, module, name, *args, **kwargs)
#     103     raise ValueError(f"name is {name}, not found in options")
#     104 cls_, base = instance.get(name)
# --> 105 return cls_(*args, **kwargs)
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/cebra/registry.py:221, in add_helper_functions.<locals>.parametrize.<locals>._create_class.<locals>._ParametrizedClass.__init__(self, *args, **kwargs)
#     219 def __init__(self, *args, **kwargs):
#     220     default_kwargs.update(kwargs)
# --> 221     super().__init__(*args, **default_kwargs)
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/cebra/datasets/allen/ca_movie_decoding.py:99, in AllenCaMoviesDataset.__init__(self, num_movie, cortex, num_neurons, split_flag, seed, test_repeat, preload)
#      97 self.split_flag = split_flag
#      98 self.test_repeat = test_repeat
# ---> 99 frame_feature = self._get_video_features(num_movie)
#     100 if preload is None:
#     101     pseudo_mice = self._get_pseudo_mice(cortex, num_movie)
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/cebra/datasets/allen/ca_movie_decoding.py:126, in AllenCaMoviesDataset._get_video_features(self, num_movie)
#     114 """Return behavior labels.
#     115
#     116 The frame feature used as the behavior labels are returned.
#    (...)
#     120
#     121 """
#     123 frame_feature_path = pathlib.Path(
#     124     _DEFAULT_DATADIR
#     125 ) / "allen" / "features" / "allen_movies" / "vit_base" / "8" / f"movie_{num_movie}_image_stack.npz" / "testfeat.pth"
# --> 126 frame_feature = torch.load(frame_feature_path)
#     127 return frame_feature
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/torch/serialization.py:997, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     994 if 'encoding' not in pickle_load_args.keys():
#     995     pickle_load_args['encoding'] = 'utf-8'
# --> 997 with _open_file_like(f, 'rb') as opened_file:
#     998     if _is_zipfile(opened_file):
#     999         # The zipfile reader is going to advance the current file position.
#    1000         # If we want to actually tail call to torch.jit.load, we need to
#    1001         # reset back to the original position.
#    1002         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/torch/serialization.py:444, in _open_file_like(name_or_buffer, mode)
#     442 def _open_file_like(name_or_buffer, mode):
#     443     if _is_path(name_or_buffer):
# --> 444         return _open_file(name_or_buffer, mode)
#     445     else:
#     446         if 'w' in mode:
#
# File ~/anaconda3/envs/cebra_packenv/lib/python3.10/site-packages/torch/serialization.py:425, in _open_file.__init__(self, name, mode)
#     424 def __init__(self, name, mode):
# --> 425     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/allen/features/allen_movies/vit_base/8/movie_one_image_stack.npz/testfeat.pth'

# %%
# helper functions
def multi_session_solver(data_loader, **kwargs):
    norm = True
    if kwargs['distance'] == 'euclidean':
        norm = False
    for dataset in data_loader.dataset.iter_sessions():
        dataset.to(kwargs['device'])

    model = torch.nn.ModuleList([
        cebra.models.init(m, dataset.input_dimension,
                          kwargs['num_hidden_units'], kwargs['output_dimension'], norm)
        for dataset, m in zip(data_loader.dataset.iter_sessions(), kwargs['model_architecture'])
    ]).to(kwargs['device'])

    for m in model:
        m.to(kwargs['device'])
    for n, dataset in enumerate(data_loader.dataset.iter_sessions()):
        dataset.configure_for(model[n])
    if kwargs['distance'] == 'euclidean':
        criterion = cebra.models.InfoMSE(temperature=kwargs['temperature'])
    elif kwargs['distance'] == 'cosine':
        criterion = cebra.models.InfoNCE(temperature=kwargs['temperature'])
    optimizer = torch.optim.Adam(itertools.chain(model.parameters(), criterion.parameters()), lr=kwargs['learning_rate'])
    return cebra.solver.MultiSessionSolver(model=model,
                                           criterion=criterion,
                                           optimizer=optimizer,
                                           tqdm_on=kwargs['verbose'])


@torch.no_grad()
def get_emissions(model, dataset):
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
    model.to(device)
    dataset.configure_for(model)
    return model(dataset[torch.arange(len(dataset))].to(device)).cpu().numpy()

def _compute_emissions_single(solver, dataset):
    return get_emissions(solver.model, dataset)

def _compute_emissions_multi(solver, dataset):

    return {
        i :
            get_emissions(model, session)
            for i, (model, session) in enumerate(zip(solver.model, dataset.iter_sessions()))
    }

# %%
train_steps = 10000

# %%
# create a loader to properly load the combined dataset
joint_loader = cebra.data.ContinuousMultiSessionDataLoader(joint_train, num_steps = train_steps, batch_size = 512, conditional = 'time_delta', time_offset=1)

# %%
cebra_joint = multi_session_solver(data_loader = joint_loader, model_architecture = ['offset1-model', 'resample1-model'],
                 distance = 'cosine', num_hidden_units = 128, output_dimension = 128,
                verbose = True, device = DEVICE, temperature = 1, learning_rate = 3e-4)

# %%
cebra_joint.fit(joint_loader)
cebra_joint_embs = _compute_emissions_multi(cebra_joint, joint_train)
# Out:
# pos: -0.9981 neg:  6.9833 total:  5.9852 temperature:  1.0000: 100%|██████████| 10000/10000 [54:05<00:00,  3.08it/s]

# %%
fig = plt.figure(figsize = (12,5))

ax1 = plt.subplot(121)
ax1.set_title('Ca, jointly trained')
ax1.scatter(cebra_joint_embs[0][:,0], cebra_joint_embs[0][:,1], cmap = 'magma', c = np.tile(np.arange(900),9), s=1)
ax1.axis('off')

ax2 = plt.subplot(122)
ax2.set_title('Neuropixel, jointly trained')
ax2.scatter(cebra_joint_embs[1][:,0], cebra_joint_embs[1][:,1], cmap = 'magma', c = np.tile(np.repeat(np.arange(900),4),9), s=1)
ax2.axis('off')
# Out:
# (-0.27719896882772443,
#  0.2904860064387321,
#  -0.1772959679365158,
#  0.23483286798000336)

# %% [markdown]
# In this example, they trained the the CEBRA model on combined data from NP and CA imaging recordings and then they used that trained model to construct individual embeddings for the NP data and CA imaging data.
